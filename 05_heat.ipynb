# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('tmp/Proyectos.csv')

df.head()

plt.figure(figsize=(10,6))
sns.countplot(x='Ejercicio', data=df, palette='coolwarm')
plt.title('Distribucion de proyectos por anio')
plt.xlabel('Anio')
plt.ylabel('Cantidad de proyectos')

plt.show()

#-------------------------------

df['Fecha de Inicio'] = pd.to_datetime(df['Fecha de Inicio'])
df['Fecha de Finalizacion'] = pd.to_datetime(df['Fecha de Finalizacion'])

df['Duracion (Dias)'] = (df['Fecha de Finalizacion'] - df['Fecha de Inicio']).dt.days

df.head()

plt.figure(figsize=(10,6))
sns.barplot(x='Rubro', y='Duracion (Dias)', data=df, estimator=lambda x: x.mean(), palette='magma')
plt.title('Duracion promedio de proyectos')
plt.xlabel('Rubro')
plt.ylabel('Duracion en dias')
plt.xticks(rotation=45)

plt.show()

#---------------
pivot_table = df.pivot_table(
    index='Tipo de Recurso',
    columns='Rubro',
    aggfunc='size',
    fill_value=0
)


plt.figure(figsize=(10,6))
sns.heatmap(pivot_table, annot=True, cmap='Blues')

plt.title('Proyectos por tipo de recurso y rubro')
plt.xlabel('Rubro')
plt.ylabel('Tipo de recurso')

plt.show()
# Out:
# C:\Users\CinthyaS\AppData\Local\Temp\ipykernel_15432\3363975849.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ejercicio', data=df, palette='coolwarm')
# C:\Users\CinthyaS\AppData\Local\Temp\ipykernel_15432\3363975849.py:19: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Fecha de Inicio'] = pd.to_datetime(df['Fecha de Inicio'])
# C:\Users\CinthyaS\AppData\Local\Temp\ipykernel_15432\3363975849.py:20: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Fecha de Finalizacion'] = pd.to_datetime(df['Fecha de Finalizacion'])
# C:\Users\CinthyaS\AppData\Local\Temp\ipykernel_15432\3363975849.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rubro', y='Duracion (Dias)', data=df, estimator=lambda x: x.mean(), palette='magma')
